# %%
# pip install pandas numpy matplotlib pillow mxnet onnx onnxruntime

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import os
import json
from PIL import Image
import onnxruntime as ort
import onnx
import requests
from io import BytesIO
import json

# %matplotlib inline

# %%
async def preprocess(image):
    # resize so that the shorter side is 256, maintaining aspect ratio
    def image_resize(image, min_len):
        image = Image.fromarray(image)
        ratio = float(min_len) / min(image.size[0], image.size[1])
        if image.size[0] > image.size[1]:
            new_size = (int(round(ratio * image.size[0])), min_len)
        else:
            new_size = (min_len, int(round(ratio * image.size[1])))
        image = image.resize(new_size, Image.BILINEAR)
        return np.array(image)
    image = image_resize(image, 256)

    # Crop centered window 224x224
    def crop_center(image, crop_w, crop_h):
        h, w, c = image.shape
        start_x = w//2 - crop_w//2
        start_y = h//2 - crop_h//2
        return image[start_y:start_y+crop_h, start_x:start_x+crop_w, :]
    image = crop_center(image, 224, 224)

    # transpose
    image = image.transpose(2, 0, 1)

    # convert the input data into the float32 input
    img_data = image.astype('float32')

    # normalize
    mean_vec = np.array([0.485, 0.456, 0.406])
    stddev_vec = np.array([0.229, 0.224, 0.225])
    norm_img_data = np.zeros(img_data.shape).astype('float32')
    for i in range(img_data.shape[0]):
        norm_img_data[i,:,:] = (img_data[i,:,:]/255 - mean_vec[i]) / stddev_vec[i]

    # add batch channel
    norm_img_data = norm_img_data.reshape(1, 3, 224, 224).astype('float32')
    return norm_img_data

async def get_tensor_from_batch(image_size, img_array, array_expected):
    k = 0
    #print(len(img_array))
    count_images = len(img_array)
    array_expected[0] = count_images
    
    # Create a NumPy array to hold the processed data
    process_array = np.empty((count_images, 3, image_size, image_size), dtype=np.float32)
    
    for i in range(count_images):
        element = img_array[i]
        data = np.asarray(element)
        preprocessed_data = await preprocess(data)
        process_array[k, :, :, :] = preprocessed_data
        k += 1

    return process_array


def get_images_array(url_array):
    # Send a GET request to the URL
    if len(url_array) == 0:
        response = requests.get("https://picsum.photos/v2/list")
        # Check if the request was successful
        if response.status_code == 200:
            # Parse the JSON response
            data = response.json()

            # Initialize an empty list to store the images
            images = []

            # Loop through the data and download/save the images
            for item in data:
                download_url = item["download_url"]

                # Send a GET request to the image URL
                image_response = requests.get(download_url)

                # Check if the image request was successful
                if image_response.status_code == 200:
                    # Open the image using PIL
                    img = Image.open(BytesIO(image_response.content))

                    # Append the image to the list
                    images.append(img)

                    # Optionally, save the image to a file
                    # img.save(f"{item['id']}.jpg")

            return images
            # Now, you have a list of PIL Image objects in the 'images' variable
        else:
            print("Failed to fetch data from the URL")
    else:
        # Initialize an empty list to store the images
        images = []
        for url in url_array:
            image_response = requests.get(url)
            # Check if the request was successful
            if image_response.status_code == 200:
                img = Image.open(BytesIO(image_response.content))

                # Append the image to the list
                images.append(img)

                # Optionally, save the image to a file
                # img.save(f"{item['id']}.jpg")
            else:
                print("Failed to fetch data from the URL")
        return images
        # Now, you have a list of PIL Image objects in the 'images' variable
        

    # You can access the images from the 'images' list and manipulate them as needed
# Post-processing function for ImageNet models


def download(content, file_name, content_type):
    with open(file_name, 'wb') as file:
        file.write(content)

def on_download(json_data, file_name):
    json_str = json.dumps(json_data)
    download(json_str.encode('utf-8'), file_name, 'text/plain')

# %%
# General function to run the ONNX model with a given input tensor
async def run_onnx_model(tensor):
    # Initialize the ONNX Runtime session
    options = ort.SessionOptions()
    options.intra_op_num_threads = 1
    options.execution_mode = ort.ExecutionMode.ORT_SEQUENTIAL
    options.add_session_config_entry('session.intra_op_thread_affinities', '1')
    options.enable_profiling=False
    ort_session = ort.InferenceSession(
            './model.onnx',
            sess_options=options,
            providers=['CPUExecutionProvider'])
    input_name = ort_session.get_inputs()[0].name
    feeds = {input_name: tensor}

    # Run the model with the input tensor and get the result
    result = ort_session.run(None, feeds)

    return result

# %%
import time
import requests

# Function to run the ONNX model with a batch of images from URLs
async def run_batch_model(image_size, array_expected, url_array, images_array, model_name):
    times = {}
    start_time = time.time()
    time_image_array = time.time()
    if len(url_array) == 0:
        url_array = url_array = ["https://i.imgur.com/b0rgmfl.jpg",
                        "https://i.imgur.com/T0wfmza.jpg",
                        "https://i.imgur.com/pX4HIwE.jpg",
                        "https://i.imgur.com/Mh0CzBL.jpg",
                        "https://i.imgur.com/ShJfWWk.jpg"]
    

    print("Getting images")
    if len(images_array) == 0:
        images_array = get_images_array(url_array)

    print("Obtained array:")
    print(images_array)

    time_image_array_elapsed = time.time() - time_image_array
    times["images"] = time_image_array_elapsed
    print("Time spent fetching images: ", time_image_array_elapsed)

    print("Getting tensor")
    time_tensor = time.time()
    tensor_images = await get_tensor_from_batch(image_size, images_array, array_expected)
    time_tensor_elapsed = time.time() - time_tensor
    times["memory"] = tensor_images.nbytes
    times["tensor"] = time_tensor_elapsed
    print("Time spent creating tensor from images: ", time_tensor_elapsed)

    print("Running model")
    time_run_model = time.time()
    result = await run_onnx_model(tensor_images)
    time_run_model_elapsed = time.time() - time_run_model
    times["model"] = time_run_model_elapsed
    print("Time spent running model: ", time_run_model_elapsed)

    finish_time = time.time() - start_time
    times["total"] = finish_time
    print("Total processing time: ", finish_time)
    #download_name = model_name + "-" + "Data-Python" + ".json"
    #on_download(json.dumps(result), download_name)
    return times

# Define the missing functions get_images_array, get_tensor_from_batch, run_onnx_model, and post_json
# These functions will depend on your specific implementation.

# %%
import asyncio
import time

# Function to run benchmark
async def run_benchmark(image_size, array_expected, url, urls_array, model_name):
    pre_images_array = get_images_array(urls_array)
    await run_batch_model(image_size, array_expected, urls_array,pre_images_array, model_name)
    
    for i in range(1,11):
        # Create arrays that will store the JSON data
        times_json = []
        times_json_avg = []
        
        # Fetch images based on the URLs
        images_array = get_images_array(urls_array)
        
        # Start the repetitions
        for rep in range(1, len(images_array) + 1):
            if rep == 21:
                break
            pre_images_array = images_array[:rep]
            print("Testing with:", len(pre_images_array), "images")
            
            # Create JSON for each repetition
            times = await run_batch_model(image_size, array_expected, urls_array, pre_images_array, model_name)
            times_json.append(times)
        
        # Save JSON data to a file for processing
        print("Json Times:", times_json)
        
        # Download JSON data
        download_name = model_name + "-" + "python" + str(i) + ".json"
        #on_download(json.dumps(times_json), download_name)
        print("Download ready")
    
    # Calculate and save average times if needed
    on_download(times_json_avg, "avg-" + model_name + "-" + backend + ".json")

# %%
result = await run_batch_model(224, [1,3,224,224],'',[],"resnet")
# Out:
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x811 at 0x1AEABC82D50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1300x866 at 0x1AEAC8D3610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=637x596 at 0x1AEAC8FFCD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x750 at 0x1AEAB5F0FD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x546 at 0x1AEAB827890>]
# Time spent fetching images:  6.297691106796265
# Getting tensor
# Time spent creating tensor from images:  0.0945291519165039
# Running model
# Time spent running model:  1.543236255645752
# Total processing time:  7.9354565143585205

# %%
await run_benchmark(224, [1,3,224,224],'',[],"resnet")
# Out:
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC915B50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8154D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCCC10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7ED90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC92B710>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC8E5510>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC915350>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC91CAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC93F110>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEABC42ED0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC816790>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8B7490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8C9C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC93FC50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7E750>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC91C750>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC817450>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC917CD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC91C2D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95B590>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3670x2462 at 0x1AEAC9156D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3008x2008 at 0x1AEAC95AD90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4434x3729 at 0x1AEAC95C850>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3887x4899 at 0x1AEAC91C910>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4855x1803 at 0x1AEAC917710>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95CF90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4209x2769 at 0x1AEAC91E9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3264x1836 at 0x1AEAC95E3D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4928x3264 at 0x1AEAC959350>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4000x2670 at 0x1AEAC91DF90>]
# Time spent fetching images:  0.001611471176147461
# Getting tensor
# Time spent creating tensor from images:  7.744495868682861
# Running model
# Time spent running model:  3.851020574569702
# Total processing time:  11.60465407371521
# Testing with: 1 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  0.43164968490600586
# Running model
# Time spent running model:  1.0244407653808594
# Total processing time:  1.4570913314819336
# Testing with: 2 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  0.5253899097442627
# Running model
# Time spent running model:  0.8456971645355225
# Total processing time:  1.3710870742797852
# Testing with: 3 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  0.6370654106140137
# Running model
# Time spent running model:  0.9219064712524414
# Total processing time:  1.561011552810669
# Testing with: 4 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  0.8279945850372314
# Running model
# Time spent running model:  1.0484867095947266
# Total processing time:  1.876481294631958
# Testing with: 5 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.034118413925171
# Running model
# Time spent running model:  1.2161433696746826
# Total processing time:  2.251291513442993
# Testing with: 6 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.2637522220611572
# Running model
# Time spent running model:  1.2860424518585205
# Total processing time:  2.552335739135742
# Testing with: 7 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.5287597179412842
# Running model
# Time spent running model:  1.4684786796569824
# Total processing time:  2.9972383975982666
# Testing with: 8 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.4426865577697754
# Running model
# Time spent running model:  1.605269193649292
# Total processing time:  3.0479557514190674
# Testing with: 9 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.7495372295379639
# Running model
# Time spent running model:  3.690659523010254
# Total processing time:  5.442197561264038
# Testing with: 10 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.5621752738952637
# Running model
# Time spent running model:  2.0001304149627686
# Total processing time:  4.562305688858032
# Testing with: 11 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.169241428375244
# Running model
# Time spent running model:  3.0017197132110596
# Total processing time:  5.170961141586304
# Testing with: 12 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.323051929473877
# Running model
# Time spent running model:  2.029754400253296
# Total processing time:  4.352806329727173
# Testing with: 13 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95F610>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.036707878112793
# Running model
# Time spent running model:  2.1065666675567627
# Total processing time:  4.143274545669556
# Testing with: 14 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95F610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96FD10>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.961907148361206
# Running model
# Time spent running model:  2.0914177894592285
# Total processing time:  4.053324937820435
# Testing with: 15 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95F610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95E050>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.9375476837158203
# Running model
# Time spent running model:  2.4483160972595215
# Total processing time:  4.386848211288452
# Testing with: 16 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95F610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95E050>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC978B90>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.0960259437561035
# Running model
# Time spent running model:  2.3527278900146484
# Total processing time:  4.448753833770752
# Testing with: 17 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95F610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95E050>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC978B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC9172D0>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.743804931640625
# Running model
# Time spent running model:  4.879159688949585
# Total processing time:  7.62296462059021
# Testing with: 18 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95F610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95E050>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC978B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC9172D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95FE50>]
# Time spent fetching images:  0.001005411148071289
# Getting tensor
# Time spent creating tensor from images:  2.3213255405426025
# Running model
# Time spent running model:  2.647345542907715
# Total processing time:  4.971307992935181
# Testing with: 19 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95F610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95E050>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC978B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC9172D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95FE50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96CB50>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  3.6784539222717285
# Running model
# Time spent running model:  2.4197418689727783
# Total processing time:  6.098195791244507
# Testing with: 20 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC96D9D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95EE90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC914650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AE92BCD890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC95FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEAC95F4D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC916B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEAC8DFD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC5CFB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC95CD50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97B550>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC914C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95F610>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96FD10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95E050>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC978B90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC9172D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC95FE50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC96CB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC97ADD0>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.3626439571380615
# Running model
# Time spent running model:  2.6475021839141846
# Total processing time:  5.010146141052246
# Json Times: [{'images': 0.0, 'memory': 602112, 'tensor': 0.43164968490600586, 'model': 1.0244407653808594, 'total': 1.4570913314819336}, {'images': 0.0, 'memory': 1204224, 'tensor': 0.5253899097442627, 'model': 0.8456971645355225, 'total': 1.3710870742797852}, {'images': 0.0, 'memory': 1806336, 'tensor': 0.6370654106140137, 'model': 0.9219064712524414, 'total': 1.561011552810669}, {'images': 0.0, 'memory': 2408448, 'tensor': 0.8279945850372314, 'model': 1.0484867095947266, 'total': 1.876481294631958}, {'images': 0.0, 'memory': 3010560, 'tensor': 1.034118413925171, 'model': 1.2161433696746826, 'total': 2.251291513442993}, {'images': 0.0, 'memory': 3612672, 'tensor': 1.2637522220611572, 'model': 1.2860424518585205, 'total': 2.552335739135742}, {'images': 0.0, 'memory': 4214784, 'tensor': 1.5287597179412842, 'model': 1.4684786796569824, 'total': 2.9972383975982666}, {'images': 0.0, 'memory': 4816896, 'tensor': 1.4426865577697754, 'model': 1.605269193649292, 'total': 3.0479557514190674}, {'images': 0.0, 'memory': 5419008, 'tensor': 1.7495372295379639, 'model': 3.690659523010254, 'total': 5.442197561264038}, {'images': 0.0, 'memory': 6021120, 'tensor': 2.5621752738952637, 'model': 2.0001304149627686, 'total': 4.562305688858032}, {'images': 0.0, 'memory': 6623232, 'tensor': 2.169241428375244, 'model': 3.0017197132110596, 'total': 5.170961141586304}, {'images': 0.0, 'memory': 7225344, 'tensor': 2.323051929473877, 'model': 2.029754400253296, 'total': 4.352806329727173}, {'images': 0.0, 'memory': 7827456, 'tensor': 2.036707878112793, 'model': 2.1065666675567627, 'total': 4.143274545669556}, {'images': 0.0, 'memory': 8429568, 'tensor': 1.961907148361206, 'model': 2.0914177894592285, 'total': 4.053324937820435}, {'images': 0.0, 'memory': 9031680, 'tensor': 1.9375476837158203, 'model': 2.4483160972595215, 'total': 4.386848211288452}, {'images': 0.0, 'memory': 9633792, 'tensor': 2.0960259437561035, 'model': 2.3527278900146484, 'total': 4.448753833770752}, {'images': 0.0, 'memory': 10235904, 'tensor': 2.743804931640625, 'model': 4.879159688949585, 'total': 7.62296462059021}, {'images': 0.001005411148071289, 'memory': 10838016, 'tensor': 2.3213255405426025, 'model': 2.647345542907715, 'total': 4.971307992935181}, {'images': 0.0, 'memory': 11440128, 'tensor': 3.6784539222717285, 'model': 2.4197418689727783, 'total': 6.098195791244507}, {'images': 0.0, 'memory': 12042240, 'tensor': 2.3626439571380615, 'model': 2.6475021839141846, 'total': 5.010146141052246}]
# Download ready
# Testing with: 1 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  0.44069600105285645
# Running model
# Time spent running model:  1.1741783618927002
# Total processing time:  1.6168758869171143
# Testing with: 2 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  0.529094934463501
# Running model
# Time spent running model:  0.8599822521209717
# Total processing time:  1.3890771865844727
# Testing with: 3 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  0.6544485092163086
# Running model
# Time spent running model:  0.9249627590179443
# Total processing time:  1.580411434173584
# Testing with: 4 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  0.8470478057861328
# Running model
# Time spent running model:  1.0773656368255615
# Total processing time:  1.92543363571167
# Testing with: 5 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.0965194702148438
# Running model
# Time spent running model:  1.1376817226409912
# Total processing time:  2.2351949214935303
# Testing with: 6 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.2757823467254639
# Running model
# Time spent running model:  1.541275978088379
# Total processing time:  2.8180558681488037
# Testing with: 7 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.314915657043457
# Running model
# Time spent running model:  1.5373098850250244
# Total processing time:  2.8532276153564453
# Testing with: 8 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.498795747756958
# Running model
# Time spent running model:  1.5581080913543701
# Total processing time:  3.056903839111328
# Testing with: 9 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.6822550296783447
# Running model
# Time spent running model:  1.7094993591308594
# Total processing time:  3.391754388809204
# Testing with: 10 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>]
# Time spent fetching images:  0.0009815692901611328
# Getting tensor
# Time spent creating tensor from images:  1.8190500736236572
# Running model
# Time spent running model:  1.758423089981079
# Total processing time:  3.5794589519500732
# Testing with: 11 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.7911098003387451
# Running model
# Time spent running model:  1.8278858661651611
# Total processing time:  3.619994878768921
# Testing with: 12 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.8890948295593262
# Running model
# Time spent running model:  1.8752129077911377
# Total processing time:  3.764307737350464
# Testing with: 13 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7D110>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  1.8961374759674072
# Running model
# Time spent running model:  2.0779175758361816
# Total processing time:  3.974055051803589
# Testing with: 14 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7D110>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABCA2710>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.2753043174743652
# Running model
# Time spent running model:  2.2424490451812744
# Total processing time:  4.51775336265564
# Testing with: 15 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7D110>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABCA2710>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DC250>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.3050038814544678
# Running model
# Time spent running model:  2.862675905227661
# Total processing time:  5.167679786682129
# Testing with: 16 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7D110>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABCA2710>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DC250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC915850>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.335005283355713
# Running model
# Time spent running model:  2.3992631435394287
# Total processing time:  4.734268426895142
# Testing with: 17 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7D110>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABCA2710>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DC250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC915850>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8B5510>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.1527698040008545
# Running model
# Time spent running model:  2.3991241455078125
# Total processing time:  4.552889347076416
# Testing with: 18 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7D110>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABCA2710>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DC250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC915850>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8B5510>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7CE10>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.1789746284484863
# Running model
# Time spent running model:  2.3906948566436768
# Total processing time:  4.569669485092163
# Testing with: 19 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7D110>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABCA2710>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DC250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC915850>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8B5510>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7CE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABDAB3D0>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.4527766704559326
# Running model
# Time spent running model:  2.425103187561035
# Total processing time:  4.8788697719573975
# Testing with: 20 images
# Getting images
# Obtained array:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D3D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD65250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEABD7EE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC8D2D10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC917C50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3334 at 0x1AEABD7EB50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC91EB10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4728x3168 at 0x1AEABD652D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3333 at 0x1AEAC958650>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5000x3269 at 0x1AEAC93D490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD6D310>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DEAD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7D110>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABCA2710>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8DC250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC915850>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEAC8B5510>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABD7CE10>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABDAB3D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1667 at 0x1AEABDB4B10>]
# Time spent fetching images:  0.0
# Getting tensor
# Time spent creating tensor from images:  2.1940762996673584
# Running model
# Time spent running model:  2.6066343784332275
# Total processing time:  4.8017449378967285
# Json Times: [{'images': 0.0, 'memory': 602112, 'tensor': 0.44069600105285645, 'model': 1.1741783618927002, 'total': 1.6168758869171143}, {'images': 0.0, 'memory': 1204224, 'tensor': 0.529094934463501, 'model': 0.8599822521209717, 'total': 1.3890771865844727}, {'images': 0.0, 'memory': 1806336, 'tensor': 0.6544485092163086, 'model': 0.9249627590179443, 'total': 1.580411434173584}, {'images': 0.0, 'memory': 2408448, 'tensor': 0.8470478057861328, 'model': 1.0773656368255615, 'total': 1.92543363571167}, {'images': 0.0, 'memory': 3010560, 'tensor': 1.0965194702148438, 'model': 1.1376817226409912, 'total': 2.2351949214935303}, {'images': 0.0, 'memory': 3612672, 'tensor': 1.2757823467254639, 'model': 1.541275978088379, 'total': 2.8180558681488037}, {'images': 0.0, 'memory': 4214784, 'tensor': 1.314915657043457, 'model': 1.5373098850250244, 'total': 2.8532276153564453}, {'images': 0.0, 'memory': 4816896, 'tensor': 1.498795747756958, 'model': 1.5581080913543701, 'total': 3.056903839111328}, {'images': 0.0, 'memory': 5419008, 'tensor': 1.6822550296783447, 'model': 1.7094993591308594, 'total': 3.391754388809204}, {'images': 0.0009815692901611328, 'memory': 6021120, 'tensor': 1.8190500736236572, 'model': 1.758423089981079, 'total': 3.5794589519500732}, {'images': 0.0, 'memory': 6623232, 'tensor': 1.7911098003387451, 'model': 1.8278858661651611, 'total': 3.619994878768921}, {'images': 0.0, 'memory': 7225344, 'tensor': 1.8890948295593262, 'model': 1.8752129077911377, 'total': 3.764307737350464}, {'images': 0.0, 'memory': 7827456, 'tensor': 1.8961374759674072, 'model': 2.0779175758361816, 'total': 3.974055051803589}, {'images': 0.0, 'memory': 8429568, 'tensor': 2.2753043174743652, 'model': 2.2424490451812744, 'total': 4.51775336265564}, {'images': 0.0, 'memory': 9031680, 'tensor': 2.3050038814544678, 'model': 2.862675905227661, 'total': 5.167679786682129}, {'images': 0.0, 'memory': 9633792, 'tensor': 2.335005283355713, 'model': 2.3992631435394287, 'total': 4.734268426895142}, {'images': 0.0, 'memory': 10235904, 'tensor': 2.1527698040008545, 'model': 2.3991241455078125, 'total': 4.552889347076416}, {'images': 0.0, 'memory': 10838016, 'tensor': 2.1789746284484863, 'model': 2.3906948566436768, 'total': 4.569669485092163}, {'images': 0.0, 'memory': 11440128, 'tensor': 2.4527766704559326, 'model': 2.425103187561035, 'total': 4.8788697719573975}, {'images': 0.0, 'memory': 12042240, 'tensor': 2.1940762996673584, 'model': 2.6066343784332275, 'total': 4.8017449378967285}]
# Download ready

# %%
def softmax(x):
    """Compute softmax values for each set of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=-1, keepdims=True)

def postprocess(scores):
    '''
    Postprocessing without mxnet gluon
    The function takes scores generated by the network and returns the class IDs in decreasing order
    of probability using numpy
    '''
    
    prob = softmax(scores)
    prob = np.squeeze(prob)
    a = np.argsort(prob)[::-1]
    return a

# %%
import numpy as np
import json

def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

def postprocess2():
    # Load labels
    with open('labels.txt', 'r') as f:
        labels = [line.strip() for line in f]

    # Load output data
    with open('output.json', 'r') as f:
        data = json.load(f)
        # Convert the score data from dictionary to numpy array
        scores = np.array(list(data['data'].values()))

    # Apply softmax to the scores
    probabilities = softmax(scores)

    # Get the indices of the scores sorted by probability
    sorted_indices = np.argsort(probabilities)[::-1]

    # Print the top prediction along with its probability
    top_prediction = sorted_indices[0]
    print(f"Class: {labels[top_prediction]}, Probability: {probabilities[top_prediction]}")

postprocess2()
# Out:
# Class: n03832673 notebook, notebook computer, Probability: 0.776560417188784

# %%
# Import JSON module
import json
 # Opening JSON file
with open('output.json') as json_file:
    result = json.load(json_file)
    
arrayResult = result['data'].map()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Tomas\Documentos\GitHub\Motivus-AnteProyecto\testing-automation\python\onnx.ipynb Cell 11 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/Tomas/Documentos/GitHub/Motivus-AnteProyecto/testing-automation/python/onnx.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> with open('output.json') as json_file:
#       <a href='vscode-notebook-cell:/c%3A/Users/Tomas/Documentos/GitHub/Motivus-AnteProyecto/testing-automation/python/onnx.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     result = json.load(json_file)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tomas/Documentos/GitHub/Motivus-AnteProyecto/testing-automation/python/onnx.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> arrayResult = result['data'].map()
#
# AttributeError: 'dict' object has no attribute 'map'

# %%
post = postprocess(list(result['data'].values()))
post
